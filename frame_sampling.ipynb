# %%
import cv2
import os

def get_video_info(video_path):
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print("Error: Tidak dapat membuka file video.")
        return None, None, None
    
    fps = cap.get(cv2.CAP_PROP_FPS)  # Frame per detik
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  # Total frame
    duration = frame_count / fps if fps > 0 else 0  # Durasi dalam detik
    
    cap.release()
    
    print(f"Durasi Video: {duration:.2f} detik")
    print(f"Frame Per Detik (FPS): {fps:.2f}")
    
    return fps, duration, frame_count

def extract_frames(video_path, output_folder, frames_per_second):
    fps, duration, frame_count = get_video_info(video_path)
    if fps is None:
        return
    
    total_frames_to_capture = int(duration * frames_per_second)
    step_size = int(frame_count / total_frames_to_capture)  # Jarak antar frame yang diambil

    os.makedirs(output_folder, exist_ok=True)

    cap = cv2.VideoCapture(video_path)
    count = 0
    frame_index = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        if frame_index % step_size == 0 and count < total_frames_to_capture:
            frame_filename = os.path.join(output_folder, f"frame_{count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            print(f"Frame {count+1} disimpan: {frame_filename}")
            count += 1
        
        frame_index += 1

    cap.release()
    print(f"Total {count} frame berhasil disimpan di {output_folder}")

# Contoh penggunaan
video_path = "videos/testing.mp4"  # Ganti dengan path video yang ingin dianalisis
output_folder = "output_frames"  # Folder penyimpanan frame

frames_per_second = int(input("Masukkan jumlah frame yang ingin diambil per detik: "))
extract_frames(video_path, output_folder, frames_per_second)
# Out:
# Masukkan jumlah frame yang ingin diambil per detik:  8
# Durasi Video: 21.41 detik
# Frame Per Detik (FPS): 59.96
# Frame 1 disimpan: output_frames\frame_0000.jpg
# Frame 2 disimpan: output_frames\frame_0001.jpg
# Frame 3 disimpan: output_frames\frame_0002.jpg
# Frame 4 disimpan: output_frames\frame_0003.jpg
# Frame 5 disimpan: output_frames\frame_0004.jpg
# Frame 6 disimpan: output_frames\frame_0005.jpg
# Frame 7 disimpan: output_frames\frame_0006.jpg
# Frame 8 disimpan: output_frames\frame_0007.jpg
# Frame 9 disimpan: output_frames\frame_0008.jpg
# Frame 10 disimpan: output_frames\frame_0009.jpg
# Frame 11 disimpan: output_frames\frame_0010.jpg
# Frame 12 disimpan: output_frames\frame_0011.jpg
# Frame 13 disimpan: output_frames\frame_0012.jpg
# Frame 14 disimpan: output_frames\frame_0013.jpg
# Frame 15 disimpan: output_frames\frame_0014.jpg
# Frame 16 disimpan: output_frames\frame_0015.jpg
# Frame 17 disimpan: output_frames\frame_0016.jpg
# Frame 18 disimpan: output_frames\frame_0017.jpg
# Frame 19 disimpan: output_frames\frame_0018.jpg
# Frame 20 disimpan: output_frames\frame_0019.jpg
# Frame 21 disimpan: output_frames\frame_0020.jpg
# Frame 22 disimpan: output_frames\frame_0021.jpg
# Frame 23 disimpan: output_frames\frame_0022.jpg
# Frame 24 disimpan: output_frames\frame_0023.jpg
# Frame 25 disimpan: output_frames\frame_0024.jpg
# Frame 26 disimpan: output_frames\frame_0025.jpg
# Frame 27 disimpan: output_frames\frame_0026.jpg
# Frame 28 disimpan: output_frames\frame_0027.jpg
# Frame 29 disimpan: output_frames\frame_0028.jpg
# Frame 30 disimpan: output_frames\frame_0029.jpg
# Frame 31 disimpan: output_frames\frame_0030.jpg
# Frame 32 disimpan: output_frames\frame_0031.jpg
# Frame 33 disimpan: output_frames\frame_0032.jpg
# Frame 34 disimpan: output_frames\frame_0033.jpg
# Frame 35 disimpan: output_frames\frame_0034.jpg
# Frame 36 disimpan: output_frames\frame_0035.jpg
# Frame 37 disimpan: output_frames\frame_0036.jpg
# Frame 38 disimpan: output_frames\frame_0037.jpg
# Frame 39 disimpan: output_frames\frame_0038.jpg
# Frame 40 disimpan: output_frames\frame_0039.jpg
# Frame 41 disimpan: output_frames\frame_0040.jpg
# Frame 42 disimpan: output_frames\frame_0041.jpg
# Frame 43 disimpan: output_frames\frame_0042.jpg
# Frame 44 disimpan: output_frames\frame_0043.jpg
# Frame 45 disimpan: output_frames\frame_0044.jpg
# Frame 46 disimpan: output_frames\frame_0045.jpg
# Frame 47 disimpan: output_frames\frame_0046.jpg
# Frame 48 disimpan: output_frames\frame_0047.jpg
# Frame 49 disimpan: output_frames\frame_0048.jpg
# Frame 50 disimpan: output_frames\frame_0049.jpg
# Frame 51 disimpan: output_frames\frame_0050.jpg
# Frame 52 disimpan: output_frames\frame_0051.jpg
# Frame 53 disimpan: output_frames\frame_0052.jpg
# Frame 54 disimpan: output_frames\frame_0053.jpg
# Frame 55 disimpan: output_frames\frame_0054.jpg
# Frame 56 disimpan: output_frames\frame_0055.jpg
# Frame 57 disimpan: output_frames\frame_0056.jpg
# Frame 58 disimpan: output_frames\frame_0057.jpg
# Frame 59 disimpan: output_frames\frame_0058.jpg
# Frame 60 disimpan: output_frames\frame_0059.jpg
# Frame 61 disimpan: output_frames\frame_0060.jpg
# Frame 62 disimpan: output_frames\frame_0061.jpg
# Frame 63 disimpan: output_frames\frame_0062.jpg
# Frame 64 disimpan: output_frames\frame_0063.jpg
# Frame 65 disimpan: output_frames\frame_0064.jpg
# Frame 66 disimpan: output_frames\frame_0065.jpg
# Frame 67 disimpan: output_frames\frame_0066.jpg
# Frame 68 disimpan: output_frames\frame_0067.jpg
# Frame 69 disimpan: output_frames\frame_0068.jpg
# Frame 70 disimpan: output_frames\frame_0069.jpg
# Frame 71 disimpan: output_frames\frame_0070.jpg
# Frame 72 disimpan: output_frames\frame_0071.jpg
# Frame 73 disimpan: output_frames\frame_0072.jpg
# Frame 74 disimpan: output_frames\frame_0073.jpg
# Frame 75 disimpan: output_frames\frame_0074.jpg
# Frame 76 disimpan: output_frames\frame_0075.jpg
# Frame 77 disimpan: output_frames\frame_0076.jpg
# Frame 78 disimpan: output_frames\frame_0077.jpg
# Frame 79 disimpan: output_frames\frame_0078.jpg
# Frame 80 disimpan: output_frames\frame_0079.jpg
# Frame 81 disimpan: output_frames\frame_0080.jpg
# Frame 82 disimpan: output_frames\frame_0081.jpg
# Frame 83 disimpan: output_frames\frame_0082.jpg
# Frame 84 disimpan: output_frames\frame_0083.jpg
# Frame 85 disimpan: output_frames\frame_0084.jpg
# Frame 86 disimpan: output_frames\frame_0085.jpg
# Frame 87 disimpan: output_frames\frame_0086.jpg
# Frame 88 disimpan: output_frames\frame_0087.jpg
# Frame 89 disimpan: output_frames\frame_0088.jpg
# Frame 90 disimpan: output_frames\frame_0089.jpg
# Frame 91 disimpan: output_frames\frame_0090.jpg
# Frame 92 disimpan: output_frames\frame_0091.jpg
# Frame 93 disimpan: output_frames\frame_0092.jpg
# Frame 94 disimpan: output_frames\frame_0093.jpg
# Frame 95 disimpan: output_frames\frame_0094.jpg
# Frame 96 disimpan: output_frames\frame_0095.jpg
# Frame 97 disimpan: output_frames\frame_0096.jpg
# Frame 98 disimpan: output_frames\frame_0097.jpg
# Frame 99 disimpan: output_frames\frame_0098.jpg
# Frame 100 disimpan: output_frames\frame_0099.jpg
# Frame 101 disimpan: output_frames\frame_0100.jpg
# Frame 102 disimpan: output_frames\frame_0101.jpg
# Frame 103 disimpan: output_frames\frame_0102.jpg
# Frame 104 disimpan: output_frames\frame_0103.jpg
# Frame 105 disimpan: output_frames\frame_0104.jpg
# Frame 106 disimpan: output_frames\frame_0105.jpg
# Frame 107 disimpan: output_frames\frame_0106.jpg
# Frame 108 disimpan: output_frames\frame_0107.jpg
# Frame 109 disimpan: output_frames\frame_0108.jpg
# Frame 110 disimpan: output_frames\frame_0109.jpg
# Frame 111 disimpan: output_frames\frame_0110.jpg
# Frame 112 disimpan: output_frames\frame_0111.jpg
# Frame 113 disimpan: output_frames\frame_0112.jpg
# Frame 114 disimpan: output_frames\frame_0113.jpg
# Frame 115 disimpan: output_frames\frame_0114.jpg
# Frame 116 disimpan: output_frames\frame_0115.jpg
# Frame 117 disimpan: output_frames\frame_0116.jpg
# Frame 118 disimpan: output_frames\frame_0117.jpg
# Frame 119 disimpan: output_frames\frame_0118.jpg
# Frame 120 disimpan: output_frames\frame_0119.jpg
# Frame 121 disimpan: output_frames\frame_0120.jpg
# Frame 122 disimpan: output_frames\frame_0121.jpg
# Frame 123 disimpan: output_frames\frame_0122.jpg
# Frame 124 disimpan: output_frames\frame_0123.jpg
# Frame 125 disimpan: output_frames\frame_0124.jpg
# Frame 126 disimpan: output_frames\frame_0125.jpg
# Frame 127 disimpan: output_frames\frame_0126.jpg
# Frame 128 disimpan: output_frames\frame_0127.jpg
# Frame 129 disimpan: output_frames\frame_0128.jpg
# Frame 130 disimpan: output_frames\frame_0129.jpg
# Frame 131 disimpan: output_frames\frame_0130.jpg
# Frame 132 disimpan: output_frames\frame_0131.jpg
# Frame 133 disimpan: output_frames\frame_0132.jpg
# Frame 134 disimpan: output_frames\frame_0133.jpg
# Frame 135 disimpan: output_frames\frame_0134.jpg
# Frame 136 disimpan: output_frames\frame_0135.jpg
# Frame 137 disimpan: output_frames\frame_0136.jpg
# Frame 138 disimpan: output_frames\frame_0137.jpg
# Frame 139 disimpan: output_frames\frame_0138.jpg
# Frame 140 disimpan: output_frames\frame_0139.jpg
# Frame 141 disimpan: output_frames\frame_0140.jpg
# Frame 142 disimpan: output_frames\frame_0141.jpg
# Frame 143 disimpan: output_frames\frame_0142.jpg
# Frame 144 disimpan: output_frames\frame_0143.jpg
# Frame 145 disimpan: output_frames\frame_0144.jpg
# Frame 146 disimpan: output_frames\frame_0145.jpg
# Frame 147 disimpan: output_frames\frame_0146.jpg
# Frame 148 disimpan: output_frames\frame_0147.jpg
# Frame 149 disimpan: output_frames\frame_0148.jpg
# Frame 150 disimpan: output_frames\frame_0149.jpg
# Frame 151 disimpan: output_frames\frame_0150.jpg
# Frame 152 disimpan: output_frames\frame_0151.jpg
# Frame 153 disimpan: output_frames\frame_0152.jpg
# Frame 154 disimpan: output_frames\frame_0153.jpg
# Frame 155 disimpan: output_frames\frame_0154.jpg
# Frame 156 disimpan: output_frames\frame_0155.jpg
# Frame 157 disimpan: output_frames\frame_0156.jpg
# Frame 158 disimpan: output_frames\frame_0157.jpg
# Frame 159 disimpan: output_frames\frame_0158.jpg
# Frame 160 disimpan: output_frames\frame_0159.jpg
# Frame 161 disimpan: output_frames\frame_0160.jpg
# Frame 162 disimpan: output_frames\frame_0161.jpg
# Frame 163 disimpan: output_frames\frame_0162.jpg
# Frame 164 disimpan: output_frames\frame_0163.jpg
# Frame 165 disimpan: output_frames\frame_0164.jpg
# Frame 166 disimpan: output_frames\frame_0165.jpg
# Frame 167 disimpan: output_frames\frame_0166.jpg
# Frame 168 disimpan: output_frames\frame_0167.jpg
# Frame 169 disimpan: output_frames\frame_0168.jpg
# Frame 170 disimpan: output_frames\frame_0169.jpg
# Frame 171 disimpan: output_frames\frame_0170.jpg
# Total 171 frame berhasil disimpan di output_frames
